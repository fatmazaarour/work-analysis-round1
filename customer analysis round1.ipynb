# %%
file1= pd.file1_excel(file1.xlxs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2492/4189418971.py in <module>
# ----> 1 file1= pd.file1_excel(file1.xlxs)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

file1 = pd.read_excel('file1.xlsx')
file1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#    Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0       0                  1000                    1/0/00   Personal Auto
# 1       0                    94                    1/0/00   Personal Auto
# 2   48767                   108                    1/0/00   Personal Auto
# 3       0                   106                    1/0/00  Corporate Auto
# 4   36357                    68                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file2 = pd.read_excel('file2.xlsx')
file3 = pd.read_excel('file3.xlsx')

# %%
file1.shape
# Out:
# (1071, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
file1.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
file2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
df = pd.concat([file1,file2,file3], axis=0)
display (df)
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN    NaN              Bachelor
# 7066  PK87824         NaN    NaN               College
# 7067  TD14365         NaN    NaN              Bachelor
# 7068  UP19263         NaN    NaN               College
# 7069  Y167826         NaN    NaN               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                        NaN       0                  1000
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# ...

# %%
df.types[axis=0]
# Out:
#   File "C:\Users\NON\AppData\Local\Temp/ipykernel_2492/986887744.py", line 1
#     df.types[axis=0]
#                  ^
# SyntaxError: invalid syntax

# %%
df.type(columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2492/2846950733.py in <module>
# ----> 1 df.type(columns)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
column_names = df.columns
display (column_names)
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount', 'State',
#        'Gender'],
#       dtype='object')

# %%
column_names.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2492/596285576.py in <module>
# ----> 1 column_names.dtypes
#
# AttributeError: 'Index' object has no attribute 'dtypes'

# %%
df.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# State                         object
# Gender                        object
# dtype: object

# %%
df.isna().sum()
# Out:
# Customer                        0
# ST                           7070
# GENDER                       7192
# Education                       0
# Customer Lifetime Value         7
# Income                          0
# Monthly Premium Auto            0
# Number of Open Complaints       0
# Policy Type                     0
# Vehicle Class                   0
# Total Claim Amount              0
# State                        2067
# Gender                       2067
# dtype: int64

# %%
df[df['Customer Lifetime Value'].isna()==True]
# Out:
#     Customer          ST GENDER             Education Customer Lifetime Value  \
# 0    RB50392  Washington    NaN                Master                     NaN
# 78   SP81997  Washington      F                Master                     NaN
# 988  GT62080  Washington      M  High School or Below                     NaN
# 325  RI52095  Washington      M  High School or Below                     NaN
# 372  HF88410  Washington    NaN  High School or Below                     NaN
# 580  MW80236  Washington      M                Master                     NaN
# 861  TO60700  Washington      F             Bachelors                     NaN
#
#      Income  Monthly Premium Auto Number of Open Complaints    Policy Type  \
# 0         0                  1000                    1/0/00  Personal Auto
# 78    41275                    96                    1/0/00  Personal Auto
# 988   55561                    63                    1/0/00  Personal Auto
# ...

# %%
df2= df[df['Customer Lifetime Value'].isna()==False]
display (df2)
# Out:
#      Customer          ST GENDER             Education  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN    NaN              Bachelor
# 7066  PK87824         NaN    NaN               College
# 7067  TD14365         NaN    NaN              Bachelor
# 7068  UP19263         NaN    NaN               College
# 7069  Y167826         NaN    NaN               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# 4                 536307.65%   36357                    68
# ...

# %%
df2.isna().sum()
# Out:
# Customer                        0
# ST                           7070
# GENDER                       7190
# Education                       0
# Customer Lifetime Value         0
# Income                          0
# Monthly Premium Auto            0
# Number of Open Complaints       0
# Policy Type                     0
# Vehicle Class                   0
# Total Claim Amount              0
# State                        2060
# Gender                       2060
# dtype: int64

# %%
df2.drop('Education')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2492/1135053562.py in <module>
# ----> 1 df2.drop('Education')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4952                 weight  1.0     0.8
#    4953         """
# -> 4954         return super().drop(
#    4955             labels=labels,
#    4956             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
# ...

# %%
df2.drop(['Education'], axis=1)
# Out:
#      Customer          ST GENDER Customer Lifetime Value  Income  \
# 1     QZ44356     Arizona      F              697953.59%       0
# 2     AI49188      Nevada      F             1288743.17%   48767
# 3     WW63253  California      M              764586.18%       0
# 4     GA49547  Washington      M              536307.65%   36357
# 5     OC83172      Oregon      F              825629.78%   62902
# ...       ...         ...    ...                     ...     ...
# 7065  LA72316         NaN    NaN             23405.98798   71941
# 7066  PK87824         NaN    NaN             3096.511217   21604
# 7067  TD14365         NaN    NaN             8163.890428       0
# 7068  UP19263         NaN    NaN             7524.442436   21941
# 7069  Y167826         NaN    NaN             2611.836866       0
#
#       Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 1                       94                    1/0/00   Personal Auto
# ...

# %%
 df2.drop(['Number of Open Complaints'], axis=1)
# Out:
#      Customer          ST GENDER             Education  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN    NaN              Bachelor
# 7066  PK87824         NaN    NaN               College
# 7067  TD14365         NaN    NaN              Bachelor
# 7068  UP19263         NaN    NaN               College
# 7069  Y167826         NaN    NaN               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto     Policy Type  \
# 1                 697953.59%       0                    94   Personal Auto
# 2                1288743.17%   48767                   108   Personal Auto
# 3                 764586.18%       0                   106  Corporate Auto
# ...

# %%
df2.isna().sum()
# Out:
# Customer                        0
# ST                           7070
# GENDER                       7190
# Education                       0
# Customer Lifetime Value         0
# Income                          0
# Monthly Premium Auto            0
# Number of Open Complaints       0
# Policy Type                     0
# Vehicle Class                   0
# Total Claim Amount              0
# State                        2060
# Gender                       2060
# dtype: int64

# %%
df3= df2[(df2['GENDER'].isna()==False) & (df2['ST'].isna()== False)]
display(df3)
# Out:
#     Customer          ST GENDER             Education Customer Lifetime Value  \
# 1    QZ44356     Arizona      F              Bachelor              697953.59%
# 2    AI49188      Nevada      F              Bachelor             1288743.17%
# 3    WW63253  California      M              Bachelor              764586.18%
# 4    GA49547  Washington      M  High School or Below              536307.65%
# 5    OC83172      Oregon      F              Bachelor              825629.78%
# ..       ...         ...    ...                   ...                     ...
# 991  HV85198     Arizona      M                Master              847141.75%
# 992  BS91566     Arizona      F               College              543121.91%
# 993  IL40123      Nevada      F               College              568964.41%
# 994  MY32149  California      F                Master              368672.38%
# 995  SA91515  California      M              Bachelor              399258.39%
#
# ...

# %%
df3.isna().sum()
# Out:
# Customer                        0
# ST                              0
# GENDER                          0
# Education                       0
# Customer Lifetime Value         0
# Income                          0
# Monthly Premium Auto            0
# Number of Open Complaints       0
# Policy Type                     0
# Vehicle Class                   0
# Total Claim Amount              0
# State                        1940
# Gender                       1940
# dtype: int64

# %%
#Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
# i couldn't find the solution
Customer_Lifetime_Value2= (Customer_Lifetime_Value)*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2492/2677362233.py in <module>
#       1 #Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
#       2 #round(df3.isna().sum()/len(df3),4)*100
# ----> 3 Customer_Lifetime_Value2= (Customer_Lifetime_Value)*100
#
# NameError: name 'Customer_Lifetime_Value' is not defined

# %%
df4=df3.drop_duplicates()
display(df4)
# Out:
#     Customer          ST GENDER             Education Customer Lifetime Value  \
# 1    QZ44356     Arizona      F              Bachelor              697953.59%
# 2    AI49188      Nevada      F              Bachelor             1288743.17%
# 3    WW63253  California      M              Bachelor              764586.18%
# 4    GA49547  Washington      M  High School or Below              536307.65%
# 5    OC83172      Oregon      F              Bachelor              825629.78%
# ..       ...         ...    ...                   ...                     ...
# 991  HV85198     Arizona      M                Master              847141.75%
# 992  BS91566     Arizona      F               College              543121.91%
# 993  IL40123      Nevada      F               College              568964.41%
# 994  MY32149  California      F                Master              368672.38%
# 995  SA91515  California      M              Bachelor              399258.39%
#
# ...

# %%
df5=df4[df4['Income']>0]
display(df5)
# Out:
#     Customer          ST GENDER             Education Customer Lifetime Value  \
# 2    AI49188      Nevada      F              Bachelor             1288743.17%
# 4    GA49547  Washington      M  High School or Below              536307.65%
# 5    OC83172      Oregon      F              Bachelor              825629.78%
# 6    XZ87318      Oregon      F               College              538089.86%
# 8    DY87989      Oregon      M              Bachelor             2412750.40%
# ..       ...         ...    ...                   ...                     ...
# 988  EX61844     Arizona      M  High School or Below             1401997.55%
# 989  QC30857      Nevada      F               College              293115.52%
# 991  HV85198     Arizona      M                Master              847141.75%
# 992  BS91566     Arizona      F               College              543121.91%
# 993  IL40123      Nevada      F               College              568964.41%
#
# ...
